# %% [markdown]
# # Preprocesamiento de datos

# %% [markdown]
# El objetivo de este notebook es realizar un preprocesamiento sobre el dataset, con el objetivo de poder utilizarlo en tareas de aprendizaje de máquina

# %% [markdown]
# ### Bibliotecas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Carga del dataset

# %%
FILE_PATH = "/home/german/Escritorio/cellphones system/Data/phone_dataset.csv"

# %%
df = pd.read_csv(FILE_PATH, encoding='utf-8', error_bad_lines=False)
# Out:
# b'Skipping line 821: expected 40 fields, saw 41\nSkipping line 6060: expected 40 fields, saw 41\nSkipping line 6663: expected 40 fields, saw 41\n'

# %%
df.head(10)
# Out:
#   brand                 model        network_technology  \
# 0  Acer         Iconia Talk S          GSM / HSPA / LTE
# 1  Acer        Liquid Z6 Plus          GSM / HSPA / LTE
# 2  Acer             Liquid Z6          GSM / HSPA / LTE
# 3  Acer  Iconia Tab 10 A3-A40  No cellular connectivity
# 4  Acer             Liquid X2          GSM / HSPA / LTE
# 5  Acer         Liquid Jade 2          GSM / HSPA / LTE
# 6  Acer      Liquid Zest Plus          GSM / HSPA / LTE
# 7  Acer           Liquid Zest          GSM / HSPA / LTE
# 8  Acer            Predator 8  No cellular connectivity
# 9  Acer     Liquid Jade Primo          GSM / HSPA / LTE
#
#                                             2G_bands  \
# 0        GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2
# 1  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 2  GSM 850 / 900 / 1800 / 1900 - SIM 1 & SIM 2 (d...
# 3                                                N/A
# 4                       GSM 850 / 900 / 1800 / 1900
# ...

# %% [markdown]
# ### Eliminación de columnas no necesarias

# %%
necessary_columns = ['brand', 'model', 'CPU', 'GPU', 'internal_memory', 'RAM', 'primary_camera', 'secondary_camera', 'battery', 'approx_price_EUR']
unused_columns = [column for column in df.columns if column not in necessary_columns]

# %%
df = df.drop(unused_columns, axis=1)

# %%
df
# Out:
#      brand                 model                            CPU  \
# 0     Acer         Iconia Talk S   Quad-core 1.3 GHz Cortex-A53
# 1     Acer        Liquid Z6 Plus   Octa-core 1.3 GHz Cortex-A53
# 2     Acer             Liquid Z6  Quad-core 1.25 GHz Cortex-A53
# 3     Acer  Iconia Tab 10 A3-A40   Quad-core 1.3 GHz Cortex-A53
# 4     Acer             Liquid X2   Octa-core 1.3 GHz Cortex-A53
# ...    ...                   ...                            ...
# 8623   ZTE                  F600                            NaN
# 8624   ZTE                  F103                            NaN
# 8625   ZTE                  F101                            NaN
# 8626   ZTE                  F100                            NaN
# 8627   ZTE       Coral200 Sollar                            NaN
#
#                 GPU internal_memory       RAM  \
# 0      Mali-T720MP2        16/32 GB  2 GB RAM
# 1      Mali-T720MP3           32 GB  3 GB RAM
# 2      Mali-T720MP2            8 GB  1 GB RAM
# ...

# %% [markdown]
# #### Eliminación de teléfonos que tienen NULL en alguna de sus características

# %%
df = df.dropna(how='any',axis=0)

# %%
df
# Out:
#      brand                 model                            CPU  \
# 0     Acer         Iconia Talk S   Quad-core 1.3 GHz Cortex-A53
# 1     Acer        Liquid Z6 Plus   Octa-core 1.3 GHz Cortex-A53
# 2     Acer             Liquid Z6  Quad-core 1.25 GHz Cortex-A53
# 3     Acer  Iconia Tab 10 A3-A40   Quad-core 1.3 GHz Cortex-A53
# 4     Acer             Liquid X2   Octa-core 1.3 GHz Cortex-A53
# ...    ...                   ...                            ...
# 8574   ZTE                 Optik     Dual-core 1.2 GHz Scorpion
# 8575   ZTE       Light Tab 2 V9A               1.4 GHz Scorpion
# 8580   ZTE                 Tania               1.0 GHz Scorpion
# 8594   ZTE                 Blade                 600 MHz ARM 11
# 8608   ZTE                 Racer                 600 MHz ARM 11
#
#                 GPU internal_memory         RAM  \
# 0      Mali-T720MP2        16/32 GB    2 GB RAM
# 1      Mali-T720MP3           32 GB    3 GB RAM
# 2      Mali-T720MP2            8 GB    1 GB RAM
# ...

# %%
df['internal_memory'].value_counts()
# Out:
# 16 GB                                    550
# 8 GB                                     457
# 4 GB                                     421
# 32 GB                                    229
# 16/32 GB                                 132
#                                         ...
# 4 GB (2.2 GB user available)               1
# 4 GB (1.9 GB accessible)                   1
# 16GB (3G model); 16/32 GB (LTE model)      1
# 16 GB (12.5 user available)                1
# 133 MB                                     1
# Name: internal_memory, Length: 117, dtype: int64

# %%
def convert_internal_memory(text)
